# %% [markdown]
# # NHL Data :: Summary
#
# This notebook provides a brief summary of the data used in the project.

# %%
import numpy as np
import pandas as pd

pbp_df = pd.read_csv('/Users/dB/Documents/repos/github/hacklytics-nhl-dashboard/.data/nhl_pbp20192020.csv')
shifts_df = pd.read_csv('/Users/dB/Documents/repos/github/hacklytics-nhl-dashboard/.data/nhl_shifts20192020.csv')
roster_df = pd.read_csv('/Users/dB/Documents/repos/github/hacklytics-nhl-dashboard/.data/roster20192020.csv')

# %%
pbp_df.head()
# Out:
#    Game_Id        Date  Period Event  \
# 0    20001  2019-10-02       1  PSTR
# 1    20001  2019-10-02       1   FAC
# 2    20001  2019-10-02       1  GOAL
# 3    20001  2019-10-02       1   FAC
# 4    20001  2019-10-02       1  MISS
#
#                                          Description Time_Elapsed  \
# 0                 Period Start- Local time: 7:13 EDT         0:00
# 1  TOR won Neu. Zone - OTT #36 WHITE vs TOR #91 T...         0:00
# 2  OTT #7 TKACHUK(1), Tip-In, Off. Zone, 4 ft.Ass...         0:25
# 3  OTT won Neu. Zone - OTT #71 TIERNEY vs TOR #88...         0:25
# 4  OTT #22 ZAITSEV, Slap, Wide of Net, Neu. Zone,...         0:38
#
#    Seconds_Elapsed Strength Ev_Zone       Type  ... Away_Score Home_Score  \
# 0              0.0      5x5     NaN        NaN  ...          0          0
# 1              0.0      5x5     Neu        NaN  ...          0          0
# 2             25.0      5x5     Off     TIP-IN  ...          0          0
# ...

# %%
print(pbp_df.columns.to_list())
# Out:
# ['Game_Id', 'Date', 'Period', 'Event', 'Description', 'Time_Elapsed', 'Seconds_Elapsed', 'Strength', 'Ev_Zone', 'Type', 'Ev_Team', 'Home_Zone', 'Away_Team', 'Home_Team', 'p1_name', 'p1_ID', 'p2_name', 'p2_ID', 'p3_name', 'p3_ID', 'awayPlayer1', 'awayPlayer1_id', 'awayPlayer2', 'awayPlayer2_id', 'awayPlayer3', 'awayPlayer3_id', 'awayPlayer4', 'awayPlayer4_id', 'awayPlayer5', 'awayPlayer5_id', 'awayPlayer6', 'awayPlayer6_id', 'homePlayer1', 'homePlayer1_id', 'homePlayer2', 'homePlayer2_id', 'homePlayer3', 'homePlayer3_id', 'homePlayer4', 'homePlayer4_id', 'homePlayer5', 'homePlayer5_id', 'homePlayer6', 'homePlayer6_id', 'Away_Players', 'Home_Players', 'Away_Score', 'Home_Score', 'Away_Goalie', 'Away_Goalie_Id', 'Home_Goalie', 'Home_Goalie_Id', 'xC', 'yC', 'Home_Coach', 'Away_Coach']

# %%
shifts_df.head()
# Out:
#    Game_Id  Period Team             Player  Player_Id  Start     End  \
# 0    20001       1  OTT     CRAIG ANDERSON    8467950    0.0  1200.0
# 1    20001       1  OTT        RON HAINSEY    8468493    0.0    25.0
# 2    20001       1  TOR       JOHN TAVARES    8475166    0.0    25.0
# 3    20001       1  TOR  FREDERIK ANDERSEN    8475883    0.0    51.0
# 4    20001       1  TOR      MORGAN RIELLY    8476853    0.0    25.0
#
#    Duration        Date
# 0    1200.0  2019-10-02
# 1      25.0  2019-10-02
# 2      25.0  2019-10-02
# 3      51.0  2019-10-02
# 4      25.0  2019-10-02

# %%
roster_df.head()
# Out:
#     # Pos               Name  Scratches     game_id
# 0   8   D        JAKE MUZZIN      False  2019020001
# 1  15   C  ALEXANDER KERFOOT      False  2019020001
# 2  16   C    MITCHELL MARNER      False  2019020001
# 3  18   L   ANDREAS JOHNSSON      False  2019020001
# 4  24   R    KASPERI KAPANEN      False  2019020001
